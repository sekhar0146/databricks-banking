-- %%
%sql

CREATE OR REPLACE TABLE main.bronze.customer_schema_demo
(
    customer_id INT,
    customer_name STRING,
    balance DECIMAL(10,2)
);

-- %%
%sql

INSERT INTO main.bronze.customer_schema_demo
VALUES
(101,'Rajesh Kumar',45000),
(102,'Priya Sharma',68000);

-- %%
%sql

SELECT *
FROM main.bronze.customer_schema_demo;

-- %% [markdown]
-- # Now imagine today's source file has an extra column.

-- %%
%sql

INSERT INTO main.bronze.customer_schema_demo
VALUES
(103,'Ananya Gupta',78000,'ananya@gmail.com');

-- %% [markdown]
-- ## In Databricks, Schema Evolution is mainly used with DataFrames (PySpark/Scala), especially when reading files like CSV, JSON, or Parquet. Useful in Pyspark code
