-- %%
CREATE SCHEMA IF NOT EXISTS main.bronze;

-- %%
SHOW CATALOGS;

-- %%
SHOW SCHEMAS;

-- %%
CREATE SCHEMA IF NOT EXISTS main.bronze;

-- %%
CREATE TABLE IF NOT EXISTS main.bronze.transactions (
    transaction_id INT,
    customer_name STRING,
    amount DECIMAL(10,2)
);

-- %%
INSERT INTO main.bronze.transactions
VALUES
(1, 'Alice', 120.50),
(2, 'Bob', 80.00),
(3, 'Charlie', 250.75);

-- %%
SELECT *
FROM main.bronze.transactions;

-- %%
UPDATE main.bronze.transactions
SET amount = 150.00
WHERE transaction_id = 1;

-- %%
SELECT *
FROM main.bronze.transactions;

-- %%
DELETE FROM main.bronze.transactions
WHERE transaction_id = 2;

-- %%
SELECT *
FROM main.bronze.transactions;

-- %%
DESCRIBE DETAIL main.bronze.transactions;

-- %%
DESCRIBE EXTENDED main.bronze.transactions;

-- %%
DESCRIBE HISTORY main.bronze.transactions;
